# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

from open_hardware_definitions import *
from open_hardware_definitions.common import DATASHEET_DIR, DEFINITIONS_DIR

from py_pdf_parser import tables
from py_pdf_parser.common import BoundingBox
from py_pdf_parser.loaders import load_file
from py_pdf_parser.visualise import visualise

from collections import namedtuple

from pprint import pprint

# %%
# Start Device definition

dev = Device(
    manufacturer='NXP',
    part_number='SPC5604',
    architecture="PowerPC",
    bit_width=32,
    endianness=Endianness.LITTLE   
)

# %%
# Load with lower char_margin to fix concatenation of columns, and also specify a custom fuzzy orderer

FUZZY_ROUNDING = 5
def fr(val):
    return round(val / FUZZY_ROUNDING) * FUZZY_ROUNDING

orderer = lambda elements: sorted(
    elements, key=lambda elem: (fr(-elem.y0), fr(elem.x0))
)

doc = load_file(os.path.join(DATASHEET_DIR, "SPC5604BF2CLL6_ref_manual.pdf"), {'char_margin': 1}, element_ordering=orderer)
content = doc.elements

# %%
# Filter out header and footer elements
header_box = BoundingBox(0, 1000, 740, 1000)
footer_box = BoundingBox(0, 1000, 0, 80)
for page in range(1, doc.number_of_pages):
    content -= content.filter_partially_within_bounding_box(header_box, page)
    content -= content.filter_partially_within_bounding_box(footer_box, page)

# %%
print(content.filter_by_text_contains("Table A-2. Detailed register map"))
# Out:
# <ElementList of 80 elements>

# %%
# Extract module base addresses
mod_base_addr_before = content.filter_by_text_contains("Table A-1. Module base addresses")[0]
mod_base_addr_after = content.after(mod_base_addr_before).filter_by_text_contains("Table A-2. Detailed register map")[0]

mod_base_addr_table_elements = content.between(mod_base_addr_before, mod_base_addr_after).filter_by_fonts("JEIOCK+Helvetica-Bold,9.0", "JEIODL+Helvetica,9.0")
mod_base_addr_table_data = mod_base_addr_table_elements.filter_by_font("JEIODL+Helvetica,9.0")

t = tables.extract_simple_table(mod_base_addr_table_data, as_text=True)

base_addr_strings = {}
modules = []
for d in t:
    name = d[0]
    if '(' in name:
        name = name.split('(')[1].split(')')[0]
    modules.append(Module(
        name=name,
        base_addr=int(d[1].replace("_", ""), 16)
    ))
    base_addr_strings[name] = d[1]

for m in modules:
    print(m)
# Out:
# Module 'Code Flash A Configuration': Base address: 0xc3f88000
# Module 'Data Flash A Configuration': Base address: 0xc3f8c000
# Module 'SIUL': Base address: 0xc3f90000
# Module 'WakeUp Unit': Base address: 0xc3f94000
# Module 'eMIOS_0': Base address: 0xc3fa0000
# Module 'eMIOS_1': Base address: 0xc3fa4000
# Module 'SSCM': Base address: 0xc3fd8000
# Module 'MC_ME': Base address: 0xc3fdc000
# Module 'FXOSC': Base address: 0xc3fe0000
# Module 'SXOSC': Base address: 0xc3fe0040
# Module 'FIRC': Base address: 0xc3fe0060
# Module 'SIRC': Base address: 0xc3fe0080
# Module 'FMPLL': Base address: 0xc3fe00a0
# Module 'CMU': Base address: 0xc3fe0100
# Module 'MC_CGM': Base address: 0xc3fe0370
# Module 'MC_RGM': Base address: 0xc3fe4000
# Module 'MC_PCU': Base address: 0xc3fe8000
# Module 'RTC/API': Base address: 0xc3fec000
# Module 'PIT': Base address: 0xc3ff0000
# Module 'ADC': Base address: 0xffe00000
# Module 'I2C': Base address: 0xffe30000
# Module 'LINFlex_0': Base address: 0xffe40000
# Module 'LINFlex_1': Base address: 0xffe44000
# Module 'LINFlex_2': Base address: 0xffe48000
# Module 'LINFlex_3': Base address: 0xffe4c000
# Module 'CTU': Base address: 0xffe64000
# Module 'CAN sampler': Base address: 0xffe70000
# Module 'MPU': Base address: 0xfff10000
# Module 'SWT': Base address: 0xfff38000
# Module 'STM': Base address: 0xfff3c000
# Module 'ECSM': Base address: 0xfff40000
# Module 'INTC': Base address: 0xfff48000
# Module 'DSPI_0': Base address: 0xfff90000
# Module 'DSPI_1': Base address: 0xfff94000
# Module 'DSPI_2': Base address: 0xfff98000
# Module 'CAN0': Base address: 0xfffc0000
# Module 'CAN1': Base address: 0xfffc4000
# Module 'CAN2': Base address: 0xfffc8000
# Module 'CAN3': Base address: 0xfffcc000
# Module 'CAN4': Base address: 0xfffd0000
# Module 'CAN5': Base address: 0xfffd4000

# %%
# Add regions (manual input for now)
dev.regions = [
    Region("Code Flash", 0x0000, 0x80000, True, True, True, False),
    Region("Code Flash Shadow", 0x200000, 0x204000 - 0x200000, True, True, True, False),
    Region("Code Flash Test", 0x400000, 0x404000 - 0x400000, True, True, True, False),
    Region("Data Flash", 0x800000, 0x810000 - 0x800000, True, True, False, False),
    Region("Data Flash Test", 0xC00000, 0xC04000 - 0xC00000, True, True, False, False),
    Region("Flash Emulation Mapping", 0x1000000, 0x20000000 - 0x1000000,True, True, True, False),
    Region("SRAM", 0x40000000, 0x4000C000 - 0x40000000, True, True, False, False),
]

# %%
# Register map (table A-4)
reg_map_before = content.filter_by_text_contains("Table A-2. Detailed register map")[0]
reg_map_after = content.after(reg_map_before).filter_by_text_contains("Appendix B")[0]
reg_map_elements = content.between(reg_map_before, reg_map_after)
print(len(reg_map_elements))
for e in reg_map_elements[:20]:
    print(e.text())
# Out:
# 8977
# Register description
# Register name
# Address
# Used
# size
# Code Flash A Configuration
# 0xC3F8_8000
# Module Configuration Register
# CFLASH_MCR
# 32-bit
# Base + 0x0000
# Low/Mid Address Space Block Locking Register
# CFLASH_LML
# 32-bit
# Base + 0x0004
# High Address Space Block Locking Register
# CFLASH_HBL
# 32-bit
# Base + 0x0008
# Secondary Low/Mid Address Space Block Locking Register
# CFLASH_SLL

# %%
# Find start elements of each module in this table
module_elements = {}
for m in modules:
    tmp_list = reg_map_elements.filter_by_text_contains(base_addr_strings[m.name])
    if len(tmp_list) > 0:
        module_elements[m.name] = tmp_list[0]
        
for m in module_elements:
    print(m)
# Out:
# Code Flash A Configuration
# Data Flash A Configuration
# SIUL
# WakeUp Unit
# eMIOS_0
# eMIOS_1
# SSCM
# MC_ME
# FXOSC
# SXOSC
# FIRC
# SIRC
# FMPLL
# CMU
# MC_CGM
# MC_RGM
# MC_PCU
# RTC/API
# PIT
# ADC
# I2C
# LINFlex_0
# LINFlex_1
# LINFlex_2
# LINFlex_3
# CTU
# CAN sampler
# MPU
# SWT
# STM
# ECSM
# INTC
# DSPI_0
# DSPI_1
# DSPI_2
# CAN0
# CAN1
# CAN2
# CAN3
# CAN4
# CAN5

# %%
dev.modules = []        
# Extract all registers for the module
for i, m in enumerate(modules):    
    print(i, m)
    if m.name not in module_elements.keys():
        continue
    if m.name in module_elements.keys() and i < (len(modules) - 1):
        tbl_contents = content.between(module_elements[m.name], module_elements[modules[i+1].name]).filter_by_font("JEIODL+Helvetica,9.0")
    elif m.name in module_elements.keys() and i == len(modules) - 1:
        tbl_contents = content.between(module_elements[m.name], reg_map_after).filter_by_font("JEIODL+Helvetica,9.0")
    
    if len(tbl_contents) == 0:
        print("Nothing for", m.name)
        continue
    
    # Get rid of "reserved" lines
    res_elements = tbl_contents.filter_by_text_contains("Reserved")
    for res_element in res_elements:
        tbl_contents -= tbl_contents.horizontally_in_line_with(res_element)
    tbl_contents -= res_elements
    
    # Extract table
    tbl = tables.extract_simple_table(tbl_contents, as_text=True, allow_gaps=True)    
    for i, r in enumerate(tbl):
        try:            
            # Parse addr
            addr = int(r[3].replace('Base + ', ''), 16) + m.base_addr
                
            # Quirks
            if '8' in r[2]:
                bit_width = 8
            elif '16' in r[2]:
                bit_width = 16
            elif '32' in r[2]:
                bit_width = 32
            elif '128' in r[2]:
                bit_width = 128
            else:
                print("NO MATCH", r[2])
            
            # Other parsing
            name = r[1].strip()
            description = r[0].strip()

            # Phew, we have everything
            m.registers.append(Register(
                name,
                addr,
                description=description,
                size_bits=bit_width,
            ))
        except Exception as e:
            print(f"CANNOT HANDLE: {r}", str(e))
            break
    
    dev.modules.append(m)
    print(f"Module '{m.name}': {len(m.registers)} registers")

print(f"Total: {sum(map(lambda m: len(m.registers), dev.modules))} registers")
# Out:
# 0 Module 'Code Flash A Configuration': Base address: 0xc3f88000
# Module 'Code Flash A Configuration': 18 registers
# 1 Module 'Data Flash A Configuration': Base address: 0xc3f8c000
# Module 'Data Flash A Configuration': 15 registers
# 2 Module 'SIUL': Base address: 0xc3f90000
# Module 'SIUL': 233 registers
# 3 Module 'WakeUp Unit': Base address: 0xc3f94000
# Module 'WakeUp Unit': 9 registers
# 4 Module 'eMIOS_0': Base address: 0xc3fa0000
# Module 'eMIOS_0': 104 registers
# 5 Module 'eMIOS_1': Base address: 0xc3fa4000
# Module 'eMIOS_1': 104 registers
# 6 Module 'SSCM': Base address: 0xc3fd8000
# Module 'SSCM': 5 registers
# 7 Module 'MC_ME': Base address: 0xc3fdc000
# Module 'MC_ME': 62 registers
# 8 Module 'FXOSC': Base address: 0xc3fe0000
# Module 'FXOSC': 1 registers
# 9 Module 'SXOSC': Base address: 0xc3fe0040
# Module 'SXOSC': 1 registers
# 10 Module 'FIRC': Base address: 0xc3fe0060
# Module 'FIRC': 1 registers
# 11 Module 'SIRC': Base address: 0xc3fe0080
# Module 'SIRC': 1 registers
# 12 Module 'FMPLL': Base address: 0xc3fe00a0
# Module 'FMPLL': 2 registers
# 13 Module 'CMU': Base address: 0xc3fe0100
# Module 'CMU': 6 registers
# 14 Module 'MC_CGM': Base address: 0xc3fe0370
# Module 'MC_CGM': 6 registers
# 15 Module 'MC_RGM': Base address: 0xc3fe4000
# Module 'MC_RGM': 9 registers
# 16 Module 'MC_PCU': Base address: 0xc3fe8000
# Module 'MC_PCU': 5 registers
# 17 Module 'RTC/API': Base address: 0xc3fec000
# Module 'RTC/API': 4 registers
# 18 Module 'PIT': Base address: 0xc3ff0000
# Module 'PIT': 25 registers
# 19 Module 'ADC': Base address: 0xffe00000
# Module 'ADC': 99 registers
# 20 Module 'I2C': Base address: 0xffe30000
# Module 'I2C': 6 registers
# 21 Module 'LINFlex_0': Base address: 0xffe40000
# Module 'LINFlex_0': 35 registers
# 22 Module 'LINFlex_1': Base address: 0xffe44000
# Module 'LINFlex_1': 16 registers
# 23 Module 'LINFlex_2': Base address: 0xffe48000
# Module 'LINFlex_2': 16 registers
# 24 Module 'LINFlex_3': Base address: 0xffe4c000
# Module 'LINFlex_3': 16 registers
# 25 Module 'CTU': Base address: 0xffe64000
# Module 'CTU': 64 registers
# 26 Module 'CAN sampler': Base address: 0xffe70000
# Module 'CAN sampler': 13 registers
# 27 Module 'MPU': Base address: 0xfff10000
# Module 'MPU': 25 registers
# 28 Module 'SWT': Base address: 0xfff38000
# Module 'SWT': 6 registers
# 29 Module 'STM': Base address: 0xfff3c000
# Module 'STM': 14 registers
# 30 Module 'ECSM': Base address: 0xfff40000
# Module 'ECSM': 18 registers
# 31 Module 'INTC': Base address: 0xfff48000
# Module 'INTC': 59 registers
# 32 Module 'DSPI_0': Base address: 0xfff90000
# Module 'DSPI_0': 20 registers
# 33 Module 'DSPI_1': Base address: 0xfff94000
# Module 'DSPI_1': 22 registers
# 34 Module 'DSPI_2': Base address: 0xfff98000
# Module 'DSPI_2': 22 registers
# 35 Module 'CAN0': Base address: 0xfffc0000
# Module 'CAN0': 140 registers
# 36 Module 'CAN1': Base address: 0xfffc4000
# Module 'CAN1': 140 registers
# 37 Module 'CAN2': Base address: 0xfffc8000
# Module 'CAN2': 140 registers
# 38 Module 'CAN3': Base address: 0xfffcc000
# Module 'CAN3': 140 registers
# 39 Module 'CAN4': Base address: 0xfffd0000
# Module 'CAN4': 140 registers
# 40 Module 'CAN5': Base address: 0xfffd4000
# Module 'CAN5': 140 registers
# Total: 1902 registers

# %%
print(dev.dump())
# Out:
# !Device
# manufacturer: NXP
# part_number: SPC5604
# architecture: PowerPC
# bit_width: 32
# endianness: little
# regions:
# - !Region
#   name: Code Flash
#   base_addr: 0x0
#   size: 0x80000
#   readable: true
#   writable: true
#   executable: true
#   volatile: false
# - !Region
#   name: Code Flash Shadow
#   base_addr: 0x200000
#   size: 0x4000
#   readable: true
#   writable: true
#   executable: true
#   volatile: false
# - !Region
#   name: Code Flash Test
#   base_addr: 0x400000
#   size: 0x4000
#   readable: true
#   writable: true
#   executable: true
#   volatile: false
# - !Region
#   name: Data Flash
#   base_addr: 0x800000
#   size: 0x10000
#   readable: true
#   writable: true
#   executable: false
#   volatile: false
# - !Region
#   name: Data Flash Test
#   base_addr: 0xc00000
#   size: 0x4000
#   readable: true
#   writable: true
#   executable: false
#   volatile: false
# - !Region
#   name: Flash Emulation Mapping
#   base_addr: 0x1000000
#   size: 0x1f000000
#   readable: true
#   writable: true
#   executable: true
#   volatile: false
# - !Region
#   name: SRAM
#   base_addr: 0x40000000
#   size: 0xc000
#   readable: true
#   writable: true
#   executable: false
#   volatile: false
# modules:
# - !Module
#   name: Code Flash A Configuration
#   base_addr: 0xc3f88000
#   registers:
#   - !Register
#     name: CFLASH_MCR
#     addr: 0xc3f88000
#     size_bits: 32
#     description: Module Configuration Register
#   - !Register
#     name: CFLASH_LML
#     addr: 0xc3f88004
#     size_bits: 32
#     description: Low/Mid Address Space Block Locking Register
#   - !Register
#     name: CFLASH_HBL
#     addr: 0xc3f88008
#     size_bits: 32
#     description: High Address Space Block Locking Register
#   - !Register
#     name: CFLASH_SLL
#     addr: 0xc3f8800c
#     size_bits: 32
#     description: Secondary Low/Mid Address Space Block Locking Register
#   - !Register
#     name: CFLASH_LMS
#     addr: 0xc3f88010
#     size_bits: 32
#     description: Low/Mid Address Space Block Select Register
#   - !Register
#     name: CFLASH_HBS
#     addr: 0xc3f88014
#     size_bits: 32
#     description: High Address Space Block Select Register
#   - !Register
#     name: CFLASH_ADR
#     addr: 0xc3f88018
#     size_bits: 32
#     description: Address Register
#   - !Register
#     name: CFLASH_BIU0
#     addr: 0xc3f8801c
#     size_bits: 32
#     description: Bus Interface Unit Register 0
#   - !Register
#     name: CFLASH_BIU1
#     addr: 0xc3f88020
#     size_bits: 32
#     description: Bus Interface Unit Register 1
#   - !Register
#     name: CFLASH_BIU2
#     addr: 0xc3f88024
#     size_bits: 32
#     description: Bus Interface Unit Register 2
#   - !Register
#     name: CFLASH_UT0
#     addr: 0xc3f8803c
#     size_bits: 32
#     description: User Test Register 0
#   - !Register
#     name: CFLASH_UT1
#     addr: 0xc3f88040
#     size_bits: 32
#     description: User Test Register 1
#   - !Register
#     name: CFLASH_UT2
#     addr: 0xc3f88044
#     size_bits: 32
#     description: User Test Register 2
#   - !Register
#     name: CFLASH_UMISR0
#     addr: 0xc3f88048
#     size_bits: 32
#     description: User Multiple Input Signature Register 0
#   - !Register
#     name: CFLASH_UMISR1
#     addr: 0xc3f8804c
#     size_bits: 32
#     description: User Multiple Input Signature Register 1
#   - !Register
#     name: CFLASH_UMISR2
#     addr: 0xc3f88050
#     size_bits: 32
#     description: User Multiple Input Signature Register 2
#   - !Register
#     name: CFLASH_UMISR3
#     addr: 0xc3f88054
#     size_bits: 32
#     description: User Multiple Input Signature Register 3
#   - !Register
#     name: CFLASH_UMISR4
#     addr: 0xc3f88058
#     size_bits: 32
#     description: User Multiple Input Signature Register 4
# - !Module
#   name: Data Flash A Configuration
#   base_addr: 0xc3f8c000
#   registers:
#   - !Register
#     name: DFLASH_MCR
#     addr: 0xc3f8c000
#     size_bits: 32
#     description: Module Configuration Register
#   - !Register
#     name: DFLASH_LML
#     addr: 0xc3f8c004
#     size_bits: 32
#     description: Low/Mid Address Space Block Locking Register
#   - !Register
#     name: DFLASH_HBL
#     addr: 0xc3f8c008
#     size_bits: 32
#     description: High Address Space Block Locking Register
#   - !Register
#     name: DFLASH_SLL
#     addr: 0xc3f8c00c
#     size_bits: 32
#     description: Secondary Low/Mid Address Space Block Locking Register
#   - !Register
#     name: DFLASH_LMS
#     addr: 0xc3f8c010
#     size_bits: 32
#     description: Low/Mid Address Space Block Select Register
#   - !Register
#     name: DFLASH_HBS
#     addr: 0xc3f8c014
#     size_bits: 32
#     description: High Address Space Block Select Register
#   - !Register
#     name: DFLASH_ADR
#     addr: 0xc3f8c018
#     size_bits: 32
#     description: Address Register
#   - !Register
#     name: DFLASH_UT0
#     addr: 0xc3f8c03c
#     size_bits: 32
#     description: User Test Register 0
#   - !Register
#     name: DFLASH_UT1
#     addr: 0xc3f8c040
#     size_bits: 32
#     description: User Test Register 1
#   - !Register
#     name: DFLASH_UT2
#     addr: 0xc3f8c044
#     size_bits: 32
#     description: User Test Register 2
#   - !Register
#     name: DFLASH_UMISR0
#     addr: 0xc3f8c048
#     size_bits: 32
#     description: User Multiple Input Signature Register 0
#   - !Register
#     name: DFLASH_UMISR1
#     addr: 0xc3f8c04c
#     size_bits: 32
#     description: User Multiple Input Signature Register 1
#   - !Register
#     name: DFLASH_UMISR2
#     addr: 0xc3f8c050
#     size_bits: 32
#     description: User Multiple Input Signature Register 2
#   - !Register
#     name: DFLASH_UMISR3
#     addr: 0xc3f8c054
#     size_bits: 32
#     description: User Multiple Input Signature Register 3
#   - !Register
#     name: DFLASH_UMISR4
#     addr: 0xc3f8c058
#     size_bits: 32
#     description: User Multiple Input Signature Register 4
# - !Module
#   name: SIUL
#   base_addr: 0xc3f90000
#   registers:
#   - !Register
#     name: MIDR1
#     addr: 0xc3f90004
#     size_bits: 32
#     description: MCU ID Register 1
#   - !Register
#     name: MIDR2
#     addr: 0xc3f90008
#     size_bits: 32
#     description: MCU ID Register 2
#   - !Register
#     name: ISR
#     addr: 0xc3f90014
#     size_bits: 32
#     description: Interrupt Status Flag Register
#   - !Register
#     name: IRER
#     addr: 0xc3f90018
#     size_bits: 32
#     description: Interrupt Request Enable Register
#   - !Register
#     name: IREER
#     addr: 0xc3f90028
#     size_bits: 32
#     description: Interrupt Rising Edge Event Enable
#   - !Register
#     name: IFEER
#     addr: 0xc3f9002c
#     size_bits: 32
#     description: Interrupt Falling-Edge Event Enable
#   - !Register
#     name: IFER
#     addr: 0xc3f90030
#     size_bits: 32
#     description: IFER Interrupt Filter Enable Register
#   - !Register
#     name: PCR0
#     addr: 0xc3f90040
#     size_bits: 16
#     description: Pad Configuration Register 0
#   - !Register
#     name: PCR1
#     addr: 0xc3f90042
#     size_bits: 16
#     description: Pad Configuration Register 1
#   - !Register
#     name: PCR2
#     addr: 0xc3f90044
#     size_bits: 16
#     description: Pad Configuration Register 2
#   - !Register
#     name: PCR3
#     addr: 0xc3f90046
#     size_bits: 16
#     description: Pad Configuration Register 3
#   - !Register
#     name: PCR4
#     addr: 0xc3f90048
#     size_bits: 16
#     description: Pad Configuration Register 4
#   - !Register
#     name: PCR5
#     addr: 0xc3f9004a
#     size_bits: 16
#     description: Pad Configuration Register 5
#   - !Register
#     name: PCR6
#     addr: 0xc3f9004c
#     size_bits: 16
#     description: Pad Configuration Register 6
#   - !Register
#     name: PCR7
#     addr: 0xc3f9004e
#     size_bits: 16
#     description: Pad Configuration Register 7
#   - !Register
#     name: PCR8
#     addr: 0xc3f90050
#     size_bits: 16
#     description: Pad Configuration Register 8
#   - !Register
#     name: PCR9
#     addr: 0xc3f90052
#     size_bits: 16
#     description: Pad Configuration Register 9
#   - !Register
#     name: PCR10
#     addr: 0xc3f90054
#     size_bits: 16
#     description: Pad Configuration Register 10
#   - !Register
#     name: PCR11
#     addr: 0xc3f90056
#     size_bits: 16
#     description: Pad Configuration Register 11
#   - !Register
#     name: PCR12
#     addr: 0xc3f90058
#     size_bits: 16
#     description: Pad Configuration Register 12
#   - !Register
#     name: PCR13
#     addr: 0xc3f9005a
#     size_bits: 16
#     description: Pad Configuration Register 13
#   - !Register
#     name: PCR14
#     addr: 0xc3f9005c
#     size_bits: 16
#     description: Pad Configuration Register 14
#   - !Register
#     name: PCR15
#     addr: 0xc3f9005e
#     size_bits: 16
#     description: Pad Configuration Register 15
#   - !Register
#     name: PCR16
#     addr: 0xc3f90060
#     size_bits: 16
#     description: Pad Configuration Register 16
#   - !Register
#     name: PCR17
#     addr: 0xc3f90062
#     size_bits: 16
#     description: Pad Configuration Register 17
#   - !Register
#     name: PCR18
#     addr: 0xc3f90064
#     size_bits: 16
#     description: Pad Configuration Register 18
#   - !Register
#     name: PCR19
#     addr: 0xc3f90066
#     size_bits: 16
#     description: Pad Configuration Register 19
#   - !Register
#     name: PCR20
#     addr: 0xc3f90068
#     size_bits: 16
#     description: Pad Configuration Register 20
#   - !Register
#     name: PCR21
#     addr: 0xc3f9006a
#     size_bits: 16
#     description: Pad Configuration Register 21
#   - !Register
#     name: PCR22
#     addr: 0xc3f9006c
#     size_bits: 16
#     description: Pad Configuration Register 22
#   - !Register
#     name: PCR23
#     addr: 0xc3f9006e
#     size_bits: 16
#     description: Pad Configuration Register 23
#   - !Register
#     name: PCR24
#     addr: 0xc3f90070
#     size_bits: 16
#     description: Pad Configuration Register 24
#   - !Register
#     name: PCR25
#     addr: 0xc3f90072
#     size_bits: 16
#     description: Pad Configuration Register 25
#   - !Register
#     name: PCR26
#     addr: 0xc3f90074
#     size_bits: 16
#     description: Pad Configuration Register 26
#   - !Register
#     name: PCR27
#     addr: 0xc3f90076
#     size_bits: 16
#     description: Pad Configuration Register 27
#   - !Register
#     name: PCR28
#     addr: 0xc3f90078
#     size_bits: 16
#     description: Pad Configuration Register 28
#   - !Register
#     name: PCR29
#     addr: 0xc3f9007a
#     size_bits: 16
#     description: Pad Configuration Register 29
#   - !Register
#     name: PCR30
#     addr: 0xc3f9007c
#     size_bits: 16
#     description: Pad Configuration Register 30
#   - !Register
#     name: PCR31
#     addr: 0xc3f9007e
#     size_bits: 16
#     description: Pad Configuration Register 31
#   - !Register
#     name: PCR32
#     addr: 0xc3f90080
#     size_bits: 16
#     description: Pad Configuration Register 32
#   - !Register
#     name: PCR33
#     addr: 0xc3f90082
#     size_bits: 16
#     description: Pad Configuration Register 33
#   - !Register
#     name: PCR34
#     addr: 0xc3f90084
#     size_bits: 16
#     description: Pad Configuration Register 34
#   - !Register
#     name: PCR35
#     addr: 0xc3f90086
#     size_bits: 16
#     description: Pad Configuration Register 35
#   - !Register
#     name: PCR36
#     addr: 0xc3f90088
#     size_bits: 16
#     description: Pad Configuration Register 36
#   - !Register
#     name: PCR37
#     addr: 0xc3f9008a
#     size_bits: 16
#     description: Pad Configuration Register 37
#   - !Register
#     name: PCR38
#     addr: 0xc3f9008c
#     size_bits: 16
#     description: Pad Configuration Register 38
#   - !Register
#     name: PCR39
#     addr: 0xc3f9008e
#     size_bits: 16
#     description: Pad Configuration Register 39
#   - !Register
#     name: PCR40
#     addr: 0xc3f90090
#     size_bits: 16
#     description: Pad Configuration Register 40
#   - !Register
#     name: PCR41
#     addr: 0xc3f90092
#     size_bits: 16
#     description: Pad Configuration Register 41
#   - !Register
#     name: PCR42
#     addr: 0xc3f90094
#     size_bits: 16
#     description: Pad Configuration Register 42
#   - !Register
#     name: PCR43
#     addr: 0xc3f90096
#     size_bits: 16
#     description: Pad Configuration Register 43
#   - !Register
#     name: PCR44
#     addr: 0xc3f90098
#     size_bits: 16
#     description: Pad Configuration Register 44
#   - !Register
#     name: PCR45
#     addr: 0xc3f9009a
#     size_bits: 16
#     description: Pad Configuration Register 45
#   - !Register
#     name: PCR46
#     addr: 0xc3f9009c
#     size_bits: 16
#     description: Pad Configuration Register 46
#   - !Register
#     name: PCR47
#     addr: 0xc3f9009e
#     size_bits: 16
#     description: Pad Configuration Register 47
#   - !Register
#     name: PCR48
#     addr: 0xc3f900a0
#     size_bits: 16
#     description: Pad Configuration Register 48
#   - !Register
#     name: PCR49
#     addr: 0xc3f900a2
#     size_bits: 16
#     description: Pad Configuration Register 49
#   - !Register
#     name: PCR50
#     addr: 0xc3f900a4
#     size_bits: 16
#     description: Pad Configuration Register 50
#   - !Register
#     name: PCR51
#     addr: 0xc3f900a6
#     size_bits: 16
#     description: Pad Configuration Register 51
#   - !Register
#     name: PCR52
#     addr: 0xc3f900a8
#     size_bits: 16
#     description: Pad Configuration Register 52
#   - !Register
#     name: PCR53
#     addr: 0xc3f900aa
#     size_bits: 16
#     description: Pad Configuration Register 53
#   - !Register
#     name: PCR54
#     addr: 0xc3f900ac
#     size_bits: 16
#     description: Pad Configuration Register 54
#   - !Register
#     name: PCR55
#     addr: 0xc3f900ae
#     size_bits: 16
#     description: Pad Configuration Register 55
#   - !Register
#     name: PCR56
#     addr: 0xc3f900b0
#     size_bits: 16
#     description: Pad Configuration Register 56
#   - !Register
#     name: PCR57
#     addr: 0xc3f900b2
#     size_bits: 16
#     description: Pad Configuration Register 57
#   - !Register
#     name: PCR58
#     addr: 0xc3f900b4
#     size_bits: 16
#     description: Pad Configuration Register 58
#   - !Register
#     name: PCR59
#     addr: 0xc3f900b6
#     size_bits: 16
#     description: Pad Configuration Register 59
#   - !Register
#     name: PCR60
#     addr: 0xc3f900b8
#     size_bits: 16
#     description: Pad Configuration Register 60
#   - !Register
#     name: PCR61
#     addr: 0xc3f900ba
#     size_bits: 16
#     description: Pad Configuration Register 61
#   - !Register
#     name: PCR62
#     addr: 0xc3f900bc
#     size_bits: 16
#     description: Pad Configuration Register 62
#   - !Register
#     name: PCR63
#     addr: 0xc3f900be
#     size_bits: 16
#     description: Pad Configuration Register 63
#   - !Register
#     name: PCR64
#     addr: 0xc3f900c0
#     size_bits: 16
#     description: Pad Configuration Register 64
#   - !Register
#     name: PCR65
#     addr: 0xc3f900c2
#     size_bits: 16
#     description: Pad Configuration Register 65
#   - !Register
#     name: PCR66
#     addr: 0xc3f900c4
#     size_bits: 16
#     description: Pad Configuration Register 66
#   - !Register
#     name: PCR67
#     addr: 0xc3f900c6
#     size_bits: 16
#     description: Pad Configuration Register 67
#   - !Register
#     name: PCR68
#     addr: 0xc3f900c8
#     size_bits: 16
#     description: Pad Configuration Register 68
#   - !Register
#     name: PCR69
#     addr: 0xc3f900ca
#     size_bits: 16
#     description: Pad Configuration Register 69
#   - !Register
#     name: PCR70
#     addr: 0xc3f900cc
#     size_bits: 16
#     description: Pad Configuration Register 70
#   - !Register
#     name: PCR71
#     addr: 0xc3f900ce
#     size_bits: 16
#     description: Pad Configuration Register 71
#   - !Register
#     name: PCR72
#     addr: 0xc3f900d0
#     size_bits: 16
#     description: Pad Configuration Register 72
#   - !Register
#     name: PCR73
#     addr: 0xc3f900d2
#     size_bits: 16
#     description: Pad Configuration Register 73
#   - !Register
#     name: PCR74
#     addr: 0xc3f900d4
#     size_bits: 16
#     description: Pad Configuration Register 74
#   - !Register
#     name: PCR75
#     addr: 0xc3f900d6
#     size_bits: 16
#     description: Pad Configuration Register 75
#   - !Register
#     name: PCR76
#     addr: 0xc3f900d8
#     size_bits: 16
#     description: Pad Configuration Register 76
#   - !Register
#     name: PCR77
#     addr: 0xc3f900da
#     size_bits: 16
#     description: Pad Configuration Register 77
#   - !Register
#     name: PCR78
#     addr: 0xc3f900dc
#     size_bits: 16
#     description: Pad Configuration Register 78
#   - !Register
#     name: PCR79
#     addr: 0xc3f900de
#     size_bits: 16
#     description: Pad Configuration Register 79
#   - !Register
#     name: PCR80
#     addr: 0xc3f900e0
#     size_bits: 16
#     description: Pad Configuration Register 80
#   - !Register
#     name: PCR81
#     addr: 0xc3f900e2
#     size_bits: 16
#     description: Pad Configuration Register 81
#   - !Register
#     name: PCR82
#     addr: 0xc3f900e4
#     size_bits: 16
#     description: Pad Configuration Register 82
#   - !Register
#     name: PCR83
#     addr: 0xc3f900e6
#     size_bits: 16
#     description: Pad Configuration Register 83
#   - !Register
#     name: PCR84
#     addr: 0xc3f900e8
#     size_bits: 16
#     description: Pad Configuration Register 84
#   - !Register
#     name: PCR85
#     addr: 0xc3f900ea
#     size_bits: 16
#     description: Pad Configuration Register 85
#   - !Register
#     name: PCR86
#     addr: 0xc3f900ec
#     size_bits: 16
#     description: Pad Configuration Register 86
#   - !Register
#     name: PCR87
#     addr: 0xc3f900ee
#     size_bits: 16
#     description: Pad Configuration Register 87
#   - !Register
#     name: PCR88
#     addr: 0xc3f900f0
#     size_bits: 16
#     description: Pad Configuration Register 88
#   - !Register
#     name: PCR89
#     addr: 0xc3f900f2
#     size_bits: 16
#     description: Pad Configuration Register 89
#   - !Register
#     name: PCR90
#     addr: 0xc3f900f4
#     size_bits: 16
#     description: Pad Configuration Register 90
#   - !Register
#     name: PCR91
#     addr: 0xc3f900f6
#     size_bits: 16
#     description: Pad Configuration Register 91
#   - !Register
#     name: PCR92
#     addr: 0xc3f900f8
#     size_bits: 16
#     description: Pad Configuration Register 92
#   - !Register
#     name: PCR93
#     addr: 0xc3f900fa
#     size_bits: 16
#     description: Pad Configuration Register 93
#   - !Register
#     name: PCR94
#     addr: 0xc3f900fc
#     size_bits: 16
#     description: Pad Configuration Register 94
#   - !Register
#     name: PCR95
#     addr: 0xc3f900fe
#     size_bits: 16
#     description: Pad Configuration Register 95
#   - !Register
#     name: PCR96
#     addr: 0xc3f90100
#     size_bits: 16
#     description: Pad Configuration Register 96
#   - !Register
#     name: PCR97
#     addr: 0xc3f90102
#     size_bits: 16
#     description: Pad Configuration Register 97
#   - !Register
#     name: PCR98
#     addr: 0xc3f90104
#     size_bits: 16
#     description: Pad Configuration Register 98
#   - !Register
#     name: PCR99
#     addr: 0xc3f90106
#     size_bits: 16
#     description: Pad Configuration Register 99
#   - !Register
#     name: PCR100
#     addr: 0xc3f90108
#     size_bits: 16
#     description: Pad Configuration Register 100
#   - !Register
#     name: PCR101
#     addr: 0xc3f9010a
#     size_bits: 16
#     description: Pad Configuration Register 101
#   - !Register
#     name: PCR102
#     addr: 0xc3f9010c
#     size_bits: 16
#     description: Pad Configuration Register 102
#   - !Register
#     name: PCR103
#     addr: 0xc3f9010e
#     size_bits: 16
#     description: Pad Configuration Register 103
#   - !Register
#     name: PCR104
#     addr: 0xc3f90110
#     size_bits: 16
#     description: Pad Configuration Register 104
#   - !Register
#     name: PCR105
#     addr: 0xc3f90112
#     size_bits: 16
#     description: Pad Configuration Register 105
#   - !Register
#     name: PCR106
#     addr: 0xc3f90114
#     size_bits: 16
#     description: Pad Configuration Register 106
#   - !Register
#     name: PCR107
#     addr: 0xc3f90116
#     size_bits: 16
#     description: Pad Configuration Register 107
#   - !Register
#     name: PCR108
#     addr: 0xc3f90118
#     size_bits: 16
#     description: Pad Configuration Register 108
#   - !Register
#     name: PCR109
#     addr: 0xc3f9011a
#     size_bits: 16
#     description: Pad Configuration Register 109
#   - !Register
#     name: PCR110
#     addr: 0xc3f9011c
#     size_bits: 16
#     description: Pad Configuration Register 110
#   - !Register
#     name: PCR111
#     addr: 0xc3f9011e
#     size_bits: 16
#     description: Pad Configuration Register 111
#   - !Register
#     name: PCR112
#     addr: 0xc3f90120
#     size_bits: 16
#     description: Pad Configuration Register 112
#   - !Register
#     name: PCR113
#     addr: 0xc3f90122
#     size_bits: 16
#     description: Pad Configuration Register 113
#   - !Register
#     name: PCR114
#     addr: 0xc3f90124
#     size_bits: 16
#     description: Pad Configuration Register 114
#   - !Register
#     name: PCR115
#     addr: 0xc3f90126
#     size_bits: 16
#     description: Pad Configuration Register 115
#   - !Register
#     name: PCR116
#     addr: 0xc3f90128
#     size_bits: 16
#     description: Pad Configuration Register 116
#   - !Register
#     name: PCR117
#     addr: 0xc3f9012a
#     size_bits: 16
#     description: Pad Configuration Register 117
#   - !Register
#     name: PCR118
#     addr: 0xc3f9012c
#     size_bits: 16
#     description: Pad Configuration Register 118
#   - !Register
#     name: PCR119
#     addr: 0xc3f9012e
#     size_bits: 16
#     description: Pad Configuration Register 119
#   - !Register
#     name: PCR120
#     addr: 0xc3f90130
#     size_bits: 16
#     description: Pad Configuration Register 120
#   - !Register
#     name: PCR121
#     addr: 0xc3f90132
#     size_bits: 16
#     description: Pad Configuration Register 121
#   - !Register
#     name: PCR122
#     addr: 0xc3f90134
#     size_bits: 16
#     description: Pad Configuration Register 122
#   - !Register
#     name: PSMI0_3
#     addr: 0xc3f90500
#     size_bits: 32
#     description: Pad Selection for Multiplexed Inputs
#   - !Register
#     name: PSMI4_7
#     addr: 0xc3f90504
#     size_bits: 32
#     description: Pad Selection for Multiplexed Inputs
#   - !Register
#     name: PSMI8_11
#     addr: 0xc3f90508
#     size_bits: 32
#     description: Pad Selection for Multiplexed Inputs
#   - !Register
#     name: PSMI12_15
#     addr: 0xc3f9050c
#     size_bits: 32
#     description: Pad Selection for Multiplexed Inputs
#   - !Register
#     name: PSMI16_19
#     addr: 0xc3f90510
#     size_bits: 32
#     description: Pad Selection for Multiplexed Inputs
#   - !Register
#     name: PSMI20_23
#     addr: 0xc3f90514
#     size_bits: 32
#     description: Pad Selection for Multiplexed Inputs
#   - !Register
#     name: PSMI24_27
#     addr: 0xc3f90518
#     size_bits: 32
#     description: Pad Selection for Multiplexed Inputs
#   - !Register
#     name: PSMI28_31
#     addr: 0xc3f9051c
#     size_bits: 32
#     description: Pad Selection for Multiplexed Inputs
#   - !Register
#     name: GPDO0_3
#     addr: 0xc3f90600
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO4_7
#     addr: 0xc3f90604
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO8_11
#     addr: 0xc3f90608
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO12_15
#     addr: 0xc3f9060c
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO16_19
#     addr: 0xc3f90610
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO20_23
#     addr: 0xc3f90614
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO24_27
#     addr: 0xc3f90618
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO28_31
#     addr: 0xc3f9061c
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO32_35
#     addr: 0xc3f90620
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO36_39
#     addr: 0xc3f90624
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO40_43
#     addr: 0xc3f90628
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO44_47
#     addr: 0xc3f9062c
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO48_51
#     addr: 0xc3f90630
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO52_55
#     addr: 0xc3f90634
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO56_59
#     addr: 0xc3f90638
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO60_63
#     addr: 0xc3f9063c
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO64_67
#     addr: 0xc3f90640
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO68_71
#     addr: 0xc3f90644
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO72_75
#     addr: 0xc3f90648
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO76_79
#     addr: 0xc3f9064c
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO80_83
#     addr: 0xc3f90650
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO84_87
#     addr: 0xc3f90654
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO88_91
#     addr: 0xc3f90658
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO92_95
#     addr: 0xc3f9065c
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO96_99
#     addr: 0xc3f90660
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO100_103
#     addr: 0xc3f90664
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO104_107
#     addr: 0xc3f90668
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO108_111
#     addr: 0xc3f9066c
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO112_115
#     addr: 0xc3f90670
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO116_119
#     addr: 0xc3f90674
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDO120_123
#     addr: 0xc3f90678
#     size_bits: 32
#     description: GPIO Pad Data Output Register
#   - !Register
#     name: GPDI0_3
#     addr: 0xc3f90800
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI4_7
#     addr: 0xc3f90804
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI8_11
#     addr: 0xc3f90808
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI12_15
#     addr: 0xc3f9080c
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI16_19
#     addr: 0xc3f90810
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI20_23
#     addr: 0xc3f90814
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI24_27
#     addr: 0xc3f90818
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI28_31
#     addr: 0xc3f9081c
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI32_35
#     addr: 0xc3f90820
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI36_39
#     addr: 0xc3f90824
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI40_43
#     addr: 0xc3f90828
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI44_47
#     addr: 0xc3f9082c
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI48_51
#     addr: 0xc3f90830
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI52_55
#     addr: 0xc3f90834
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI56_59
#     addr: 0xc3f90838
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI60_63
#     addr: 0xc3f9083c
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI64_67
#     addr: 0xc3f90840
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI68_71
#     addr: 0xc3f90844
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI72_75
#     addr: 0xc3f90848
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI76_79
#     addr: 0xc3f9084c
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI80_83
#     addr: 0xc3f90850
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI84_87
#     addr: 0xc3f90854
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI88_91
#     addr: 0xc3f90858
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI92_95
#     addr: 0xc3f9085c
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI96_99
#     addr: 0xc3f90860
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI100_103
#     addr: 0xc3f90864
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI104_107
#     addr: 0xc3f90868
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI108_111
#     addr: 0xc3f9086c
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI112_115
#     addr: 0xc3f90870
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI116_119
#     addr: 0xc3f90874
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: GPDI120_123
#     addr: 0xc3f90878
#     size_bits: 32
#     description: GPIO Pad Data Input Register
#   - !Register
#     name: PGPDO0
#     addr: 0xc3f90c00
#     size_bits: 32
#     description: Parallel GPIO Pad Data Out Register
#   - !Register
#     name: PGPDO1
#     addr: 0xc3f90c04
#     size_bits: 32
#     description: Parallel GPIO Pad Data Out Register
#   - !Register
#     name: PGPDO2
#     addr: 0xc3f90c08
#     size_bits: 32
#     description: Parallel GPIO Pad Data Out Register
#   - !Register
#     name: PGPDO3
#     addr: 0xc3f90c0c
#     size_bits: 32
#     description: Parallel GPIO Pad Data Out Register
#   - !Register
#     name: PGPDI0
#     addr: 0xc3f90c40
#     size_bits: 32
#     description: Parallel GPIO Pad Data In Register
#   - !Register
#     name: PGPDI1
#     addr: 0xc3f90c44
#     size_bits: 32
#     description: Parallel GPIO Pad Data In Register
#   - !Register
#     name: PGPDI2
#     addr: 0xc3f90c48
#     size_bits: 32
#     description: Parallel GPIO Pad Data In Register
#   - !Register
#     name: PGPDI3
#     addr: 0xc3f90c4c
#     size_bits: 32
#     description: Parallel GPIO Pad Data In Register
#   - !Register
#     name: MPGPDO0
#     addr: 0xc3f90c80
#     size_bits: 32
#     description: Masked Parallel GPIO Pad Data Out Register
#   - !Register
#     name: MPGPDO1
#     addr: 0xc3f90c84
#     size_bits: 32
#     description: Masked Parallel GPIO Pad Data Out Register
#   - !Register
#     name: MPGPDO2
#     addr: 0xc3f90c88
#     size_bits: 32
#     description: Masked Parallel GPIO Pad Data Out Register
#   - !Register
#     name: MPGPDO3
#     addr: 0xc3f90c8c
#     size_bits: 32
#     description: Masked Parallel GPIO Pad Data Out Register
#   - !Register
#     name: MPGPDO4
#     addr: 0xc3f90c90
#     size_bits: 32
#     description: Masked Parallel GPIO Pad Data Out Register
#   - !Register
#     name: MPGPDO5
#     addr: 0xc3f90c94
#     size_bits: 32
#     description: Masked Parallel GPIO Pad Data Out Register
#   - !Register
#     name: MPGPDO6
#     addr: 0xc3f90c98
#     size_bits: 32
#     description: Masked Parallel GPIO Pad Data Out Register
#   - !Register
#     name: MPGPDO7
#     addr: 0xc3f90c9c
#     size_bits: 32
#     description: Masked Parallel GPIO Pad Data Out Register
#   - !Register
#     name: IFMC0
#     addr: 0xc3f91000
#     size_bits: 32
#     description: Interrupt Filter Maximum Counter Register
#   - !Register
#     name: IFMC1
#     addr: 0xc3f91004
#     size_bits: 32
#     description: Interrupt Filter Maximum Counter Register
#   - !Register
#     name: IFMC2
#     addr: 0xc3f91008
#     size_bits: 32
#     description: Interrupt Filter Maximum Counter Register
#   - !Register
#     name: IFMC3
#     addr: 0xc3f9100c
#     size_bits: 32
#     description: Interrupt Filter Maximum Counter Register
#   - !Register
#     name: IFMC4
#     addr: 0xc3f91010
#     size_bits: 32
#     description: Interrupt Filter Maximum Counter Register
#   - !Register
#     name: FMC5
#     addr: 0xc3f91014
#     size_bits: 32
#     description: Interrupt Filter Maximum Counter Register
#   - !Register
#     name: IFMC6
#     addr: 0xc3f91018
#     size_bits: 32
#     description: Interrupt Filter Maximum Counter Register
#   - !Register
#     name: IFMC7
#     addr: 0xc3f9101c
#     size_bits: 32
#     description: Interrupt Filter Maximum Counter Register
#   - !Register
#     name: IFMC8
#     addr: 0xc3f91020
#     size_bits: 32
#     description: Interrupt Filter Maximum Counter Register
#   - !Register
#     name: IFMC9
#     addr: 0xc3f91024
#     size_bits: 32
#     description: Interrupt Filter Maximum Counter Register
#   - !Register
#     name: IFMC10
#     addr: 0xc3f91028
#     size_bits: 32
#     description: Interrupt Filter Maximum Counter Register
#   - !Register
#     name: IFMC11
#     addr: 0xc3f9102c
#     size_bits: 32
#     description: Interrupt Filter Maximum Counter Register
#   - !Register
#     name: IFMC12
#     addr: 0xc3f91030
#     size_bits: 32
#     description: Interrupt Filter Maximum Counter Register
#   - !Register
#     name: IFMC13
#     addr: 0xc3f91034
#     size_bits: 32
#     description: Interrupt Filter Maximum Counter Register
#   - !Register
#     name: IFMC14
#     addr: 0xc3f91038
#     size_bits: 32
#     description: Interrupt Filter Maximum Counter Register
#   - !Register
#     name: IFMC15
#     addr: 0xc3f9103c
#     size_bits: 32
#     description: Interrupt Filter Maximum Counter Register
#   - !Register
#     name: IFCP
#     addr: 0xc3f91080
#     size_bits: 32
#     description: Inerrupt Filter Clock Prescaler Register
# - !Module
#   name: WakeUp Unit
#   base_addr: 0xc3f94000
#   registers:
#   - !Register
#     name: WKPU_NSR
#     addr: 0xc3f94000
#     size_bits: 32
#     description: NMI Status Flag Register
#   - !Register
#     name: WKPU_NCR
#     addr: 0xc3f94008
#     size_bits: 32
#     description: NMI Configuration Register
#   - !Register
#     name: WKPU_WISR
#     addr: 0xc3f94014
#     size_bits: 32
#     description: Wakeup/Interrupt Status Flag Register
#   - !Register
#     name: WKPU_IRER
#     addr: 0xc3f94018
#     size_bits: 32
#     description: Interrupt Request Enable Register
#   - !Register
#     name: WKPU_WRER
#     addr: 0xc3f9401c
#     size_bits: 32
#     description: Wakeup Request Enable Register
#   - !Register
#     name: WKPU_WIREER
#     addr: 0xc3f94028
#     size_bits: 32
#     description: Wakeup/Interrupt Rising-Edge Event Enable Register
#   - !Register
#     name: WKPU_WIFEER
#     addr: 0xc3f9402c
#     size_bits: 32
#     description: Wakeup/Interrupt Falling-Edge Event Enable Register
#   - !Register
#     name: WKPU_WIFER
#     addr: 0xc3f94030
#     size_bits: 32
#     description: Wakeup/Interrupt Filter Enable Register
#   - !Register
#     name: WKPU_WIPUER
#     addr: 0xc3f94034
#     size_bits: 32
#     description: Wakeup/Interrupt Pullup Enable Register
# - !Module
#   name: eMIOS_0
#   base_addr: 0xc3fa0000
#   registers:
#   - !Register
#     name: EMIOS0_MCR
#     addr: 0xc3fa0000
#     size_bits: 32
#     description: EMIOS Module Configuration Register
#   - !Register
#     name: EMIOS0_GFLAG
#     addr: 0xc3fa0004
#     size_bits: 32
#     description: EMIOS Global FLAG Register
#   - !Register
#     name: EMIOS0_OUDIS
#     addr: 0xc3fa0008
#     size_bits: 32
#     description: EMIOS Output Update Disable Register
#   - !Register
#     name: EMIOS0_UCDIS
#     addr: 0xc3fa000c
#     size_bits: 32
#     description: EMIOS Disable Channel Register
#   - !Register
#     name: EMIOS0_UC0_A
#     addr: 0xc3fa0020
#     size_bits: 32
#     description: eMIOS_0 UC0 A Register
#   - !Register
#     name: EMIOS0_UC0_B
#     addr: 0xc3fa0024
#     size_bits: 32
#     description: eMIOS_0 UC0 B Register
#   - !Register
#     name: EMIOS0_UC0_CNT
#     addr: 0xc3fa0028
#     size_bits: 32
#     description: eMIOS_0 UC0 CNT
#   - !Register
#     name: EMIOS0_UC0_SC
#     addr: 0xc3fa002c
#     size_bits: 32
#     description: eMIOS_0 UC0 Control Register
#   - !Register
#     name: EMIOS0_UC0_SS
#     addr: 0xc3fa0030
#     size_bits: 32
#     description: eMIOS_0 UC0 Status Register
#   - !Register
#     name: EMIOS0_UC1_A
#     addr: 0xc3fa0040
#     size_bits: 32
#     description: eMIOS_0 UC1 A Register
#   - !Register
#     name: EMIOS0_UC1_B
#     addr: 0xc3fa0044
#     size_bits: 32
#     description: eMIOS_0 UC1 B Register
#   - !Register
#     name: EMIOS0_UC1_SC
#     addr: 0xc3fa004c
#     size_bits: 32
#     description: eMIOS_0 UC1 Control Register
#   - !Register
#     name: EMIOS0_UC1_SS
#     addr: 0xc3fa0050
#     size_bits: 32
#     description: eMIOS_0 UC1 Status Register
#   - !Register
#     name: EMIOS0_UC2_A
#     addr: 0xc3fa0060
#     size_bits: 32
#     description: eMIOS_0 UC2 A Register
#   - !Register
#     name: EMIOS0_UC2_B
#     addr: 0xc3fa0064
#     size_bits: 32
#     description: eMIOS_0 UC2 B Register
#   - !Register
#     name: EMIOS0_UC2_SC
#     addr: 0xc3fa006c
#     size_bits: 32
#     description: eMIOS_0 UC2 Control Register
#   - !Register
#     name: EMIOS0_UC2_SS
#     addr: 0xc3fa0070
#     size_bits: 32
#     description: eMIOS_0 UC2 Status Register
#   - !Register
#     name: EMIOS0_UC3_A
#     addr: 0xc3fa0080
#     size_bits: 32
#     description: eMIOS_0 UC3 A Register
#   - !Register
#     name: EMIOS0_UC3_B
#     addr: 0xc3fa0084
#     size_bits: 32
#     description: eMIOS_0 UC3 B Register
#   - !Register
#     name: EMIOS0_UC3_SC
#     addr: 0xc3fa008c
#     size_bits: 32
#     description: eMIOS_0 UC3 Control Register
#   - !Register
#     name: EMIOS0_UC3_SS
#     addr: 0xc3fa0090
#     size_bits: 32
#     description: eMIOS_0 UC3 Status Register
#   - !Register
#     name: EMIOS0_UC4_A
#     addr: 0xc3fa00a0
#     size_bits: 32
#     description: eMIOS_0 UC4 A Register
#   - !Register
#     name: EMIOS0_UC4_B
#     addr: 0xc3fa00a4
#     size_bits: 32
#     description: eMIOS_0 UC4 B Register
#   - !Register
#     name: EMIOS0_UC4_SC
#     addr: 0xc3fa00ac
#     size_bits: 32
#     description: eMIOS_0 UC4 Control Register
#   - !Register
#     name: EMIOS0_UC4_SS
#     addr: 0xc3fa00b0
#     size_bits: 32
#     description: eMIOS_0 UC4 Status Register
#   - !Register
#     name: EMIOS0_UC5_A
#     addr: 0xc3fa00c0
#     size_bits: 32
#     description: eMIOS_0 UC5 A Register
#   - !Register
#     name: EMIOS0_UC5_B
#     addr: 0xc3fa00c4
#     size_bits: 32
#     description: eMIOS_0 UC5 B Register
#   - !Register
#     name: EMIOS0_UC5_SC
#     addr: 0xc3fa00cc
#     size_bits: 32
#     description: eMIOS_0 UC5 Control Register
#   - !Register
#     name: EMIOS0_UC5_SS
#     addr: 0xc3fa00d0
#     size_bits: 32
#     description: eMIOS_0 UC5 Status Register
#   - !Register
#     name: EMIOS0_UC6_A
#     addr: 0xc3fa00e0
#     size_bits: 32
#     description: eMIOS_0 UC6 A Register
#   - !Register
#     name: EMIOS0_UC6_B
#     addr: 0xc3fa00e4
#     size_bits: 32
#     description: eMIOS_0 UC6 B Register
#   - !Register
#     name: EMIOS0_UC6_SC
#     addr: 0xc3fa00ec
#     size_bits: 32
#     description: eMIOS_0 UC6 Control Register
#   - !Register
#     name: EMIOS0_UC6_SS
#     addr: 0xc3fa00f0
#     size_bits: 32
#     description: eMIOS_0 UC6 Status Register
#   - !Register
#     name: EMIOS0_UC7_A
#     addr: 0xc3fa0100
#     size_bits: 32
#     description: eMIOS_0 UC7 A Register
#   - !Register
#     name: EMIOS0_UC7_B
#     addr: 0xc3fa0104
#     size_bits: 32
#     description: eMIOS_0 UC7 B Register
#   - !Register
#     name: EMIOS0_UC7_SC
#     addr: 0xc3fa010c
#     size_bits: 32
#     description: eMIOS_0 UC7 Control Register
#   - !Register
#     name: EMIOS0_UC7_SS
#     addr: 0xc3fa0110
#     size_bits: 32
#     description: eMIOS_0 UC7 Status Register
#   - !Register
#     name: EMIOS0_UC8_A
#     addr: 0xc3fa0120
#     size_bits: 32
#     description: eMIOS_0 UC8 A Register
#   - !Register
#     name: EMIOS0_UC8_B
#     addr: 0xc3fa0124
#     size_bits: 32
#     description: eMIOS_0 UC8 B Register
#   - !Register
#     name: EMIOS0_UC8_CNT
#     addr: 0xc3fa0128
#     size_bits: 32
#     description: eMIOS_0 UC8 CNT
#   - !Register
#     name: EMIOS0_UC8_SC
#     addr: 0xc3fa012c
#     size_bits: 32
#     description: eMIOS_0 UC8 Control Register
#   - !Register
#     name: EMIOS0_UC8_SS
#     addr: 0xc3fa0130
#     size_bits: 32
#     description: eMIOS_0 UC8 Status Register
#   - !Register
#     name: EMIOS0_UC9_A
#     addr: 0xc3fa0140
#     size_bits: 32
#     description: eMIOS_0 UC9 A Register
#   - !Register
#     name: EMIOS0_UC9_B
#     addr: 0xc3fa0144
#     size_bits: 32
#     description: eMIOS_0 UC9 B Register
#   - !Register
#     name: EMIOS0_UC9_SC
#     addr: 0xc3fa014c
#     size_bits: 32
#     description: eMIOS_0 UC9 Control Register
#   - !Register
#     name: EMIOS0_UC9_SS
#     addr: 0xc3fa0150
#     size_bits: 32
#     description: eMIOS_0 UC9 Status Register
#   - !Register
#     name: EMIOS0_UC10_A
#     addr: 0xc3fa0160
#     size_bits: 32
#     description: eMIOS_0 UC10 A Register
#   - !Register
#     name: EMIOS0_UC10_B
#     addr: 0xc3fa0164
#     size_bits: 32
#     description: eMIOS_0 UC10 B Register
#   - !Register
#     name: EMIOS0_UC10_SC
#     addr: 0xc3fa016c
#     size_bits: 32
#     description: eMIOS_0 UC10 Control Register
#   - !Register
#     name: EMIOS0_UC10_SS
#     addr: 0xc3fa0170
#     size_bits: 32
#     description: eMIOS_0 UC10 Status Register
#   - !Register
#     name: EMIOS0_UC11_A
#     addr: 0xc3fa0180
#     size_bits: 32
#     description: eMIOS_0 UC11 A Register
#   - !Register
#     name: EMIOS0_UC11_B
#     addr: 0xc3fa0184
#     size_bits: 32
#     description: eMIOS_0 UC11 B Register
#   - !Register
#     name: EMIOS0_UC11_SC
#     addr: 0xc3fa018c
#     size_bits: 32
#     description: eMIOS_0 UC11 Control Register
#   - !Register
#     name: EMIOS0_UC11_SS
#     addr: 0xc3fa0190
#     size_bits: 32
#     description: eMIOS_0 UC11 Status Register
#   - !Register
#     name: EMIOS0_UC12_A
#     addr: 0xc3fa01a0
#     size_bits: 32
#     description: eMIOS_0 UC12 A Register
#   - !Register
#     name: EMIOS0_UC12_B
#     addr: 0xc3fa01a4
#     size_bits: 32
#     description: eMIOS_0 UC12 B Register
#   - !Register
#     name: EMIOS0_UC12_SC
#     addr: 0xc3fa01ac
#     size_bits: 32
#     description: eMIOS_0 UC12 Control Register
#   - !Register
#     name: EMIOS0_UC12_SS
#     addr: 0xc3fa01b0
#     size_bits: 32
#     description: eMIOS_0 UC12 Status Register
#   - !Register
#     name: EMIOS0_UC13_A
#     addr: 0xc3fa01c0
#     size_bits: 32
#     description: eMIOS_0 UC13 A Register
#   - !Register
#     name: EMIOS0_UC13_B
#     addr: 0xc3fa01c4
#     size_bits: 32
#     description: eMIOS_0 UC13 B Register
#   - !Register
#     name: EMIOS0_UC13_SC
#     addr: 0xc3fa01cc
#     size_bits: 32
#     description: eMIOS_0 UC13 Control Register
#   - !Register
#     name: EMIOS0_UC13_SS
#     addr: 0xc3fa01d0
#     size_bits: 32
#     description: eMIOS_0 UC13 Status Register
#   - !Register
#     name: EMIOS0_UC14_A
#     addr: 0xc3fa01e0
#     size_bits: 32
#     description: eMIOS_0 UC14 A Register
#   - !Register
#     name: EMIOS0_UC14_B
#     addr: 0xc3fa01e4
#     size_bits: 32
#     description: eMIOS_0 UC14 B Register
#   - !Register
#     name: EMIOS0_UC14_SC
#     addr: 0xc3fa01ec
#     size_bits: 32
#     description: eMIOS_0 UC14 Control Register
#   - !Register
#     name: EMIOS0_UC14_SS
#     addr: 0xc3fa01f0
#     size_bits: 32
#     description: eMIOS_0 UC14 Status Register
#   - !Register
#     name: EMIOS0_UC15_A
#     addr: 0xc3fa0200
#     size_bits: 32
#     description: eMIOS_0 UC15 A Register
#   - !Register
#     name: EMIOS0_UC15_B
#     addr: 0xc3fa0204
#     size_bits: 32
#     description: eMIOS_0 UC15 B Register
#   - !Register
#     name: EMIOS0_UC15_SC
#     addr: 0xc3fa020c
#     size_bits: 32
#     description: eMIOS_0 UC15 Control Register
#   - !Register
#     name: EMIOS0_UC15_SS
#     addr: 0xc3fa0210
#     size_bits: 32
#     description: eMIOS_0 UC15 Status Register
#   - !Register
#     name: EMIOS0_UC16_A
#     addr: 0xc3fa0220
#     size_bits: 32
#     description: eMIOS_0 UC16 A Register
#   - !Register
#     name: EMIOS0_UC16_B
#     addr: 0xc3fa0224
#     size_bits: 32
#     description: eMIOS_0 UC16 B Register
#   - !Register
#     name: EMIOS0_UC16_CNT
#     addr: 0xc3fa0228
#     size_bits: 32
#     description: eMIOS_0 UC16 CNT
#   - !Register
#     name: EMIOS0_UC16_SC
#     addr: 0xc3fa022c
#     size_bits: 32
#     description: eMIOS_0 UC16 Control Register
#   - !Register
#     name: EMIOS0_UC16_SS
#     addr: 0xc3fa0230
#     size_bits: 32
#     description: eMIOS_0 UC16 Status Register
#   - !Register
#     name: EMIOS0_UC17_A
#     addr: 0xc3fa0240
#     size_bits: 32
#     description: eMIOS_0 UC17 A Register
#   - !Register
#     name: EMIOS0_UC17_B
#     addr: 0xc3fa0244
#     size_bits: 32
#     description: eMIOS_0 UC17 B Register
#   - !Register
#     name: EMIOS0_UC17_SC
#     addr: 0xc3fa024c
#     size_bits: 32
#     description: eMIOS_0 UC17 Control Register
#   - !Register
#     name: EMIOS0_UC17_SS
#     addr: 0xc3fa0250
#     size_bits: 32
#     description: eMIOS_0 UC17 Status Register
#   - !Register
#     name: EMIOS0_UC18_A
#     addr: 0xc3fa0260
#     size_bits: 32
#     description: eMIOS_0 UC18 A Register
#   - !Register
#     name: EMIOS0_UC18_B
#     addr: 0xc3fa0264
#     size_bits: 32
#     description: eMIOS_0 UC18 B Register
#   - !Register
#     name: EMIOS0_UC18_SC
#     addr: 0xc3fa026c
#     size_bits: 32
#     description: eMIOS_0 UC18 Control Register
#   - !Register
#     name: EMIOS0_UC18_SS
#     addr: 0xc3fa0270
#     size_bits: 32
#     description: eMIOS_0 UC18 Status Register
#   - !Register
#     name: EMIOS0_UC19_A
#     addr: 0xc3fa0280
#     size_bits: 32
#     description: eMIOS_0 UC19 A Register
#   - !Register
#     name: EMIOS0_UC19_B
#     addr: 0xc3fa0284
#     size_bits: 32
#     description: eMIOS_0 UC19 B Register
#   - !Register
#     name: EMIOS0_UC19_SC
#     addr: 0xc3fa028c
#     size_bits: 32
#     description: eMIOS_0 UC19 Control Register
#   - !Register
#     name: EMIOS0_UC19_SS
#     addr: 0xc3fa0290
#     size_bits: 32
#     description: eMIOS_0 UC19 Status Register
#   - !Register
#     name: EMIOS0_UC20_A
#     addr: 0xc3fa02a0
#     size_bits: 32
#     description: eMIOS_0 UC20 A Register
#   - !Register
#     name: EMIOS0_UC20_B
#     addr: 0xc3fa02a4
#     size_bits: 32
#     description: eMIOS_0 UC20 B Register
#   - !Register
#     name: EMIOS0_UC20_SC
#     addr: 0xc3fa02ac
#     size_bits: 32
#     description: eMIOS_0 UC20 Control Register
#   - !Register
#     name: EMIOS0_UC20_SS
#     addr: 0xc3fa02b0
#     size_bits: 32
#     description: eMIOS_0 UC20 Status Register
#   - !Register
#     name: EMIOS0_UC21_A
#     addr: 0xc3fa02c0
#     size_bits: 32
#     description: eMIOS_0 UC21 A Register
#   - !Register
#     name: EMIOS0_UC21_B
#     addr: 0xc3fa02c4
#     size_bits: 32
#     description: eMIOS_0 UC21 B Register
#   - !Register
#     name: EMIOS0_UC21_SC
#     addr: 0xc3fa02cc
#     size_bits: 32
#     description: eMIOS_0 UC21 Control Register
#   - !Register
#     name: EMIOS0_UC21_SS
#     addr: 0xc3fa02d0
#     size_bits: 32
#     description: eMIOS_0 UC21 Status Register
#   - !Register
#     name: EMIOS0_UC22_A
#     addr: 0xc3fa02e0
#     size_bits: 32
#     description: eMIOS_0 UC22 A Register
#   - !Register
#     name: EMIOS0_UC22_B
#     addr: 0xc3fa02e4
#     size_bits: 32
#     description: eMIOS_0 UC22 B Register
#   - !Register
#     name: EMIOS0_UC22_SC
#     addr: 0xc3fa02ec
#     size_bits: 32
#     description: eMIOS_0 UC22 Control Register
#   - !Register
#     name: EMIOS0_UC22_SS
#     addr: 0xc3fa02f0
#     size_bits: 32
#     description: eMIOS_0 UC22 Status Register
#   - !Register
#     name: EMIOS0_UC23_A
#     addr: 0xc3fa0300
#     size_bits: 32
#     description: eMIOS_0 UC23 A Register
#   - !Register
#     name: EMIOS0_UC23_B
#     addr: 0xc3fa0304
#     size_bits: 32
#     description: eMIOS_0 UC23 B Register
#   - !Register
#     name: EMIOS0_UC23_CNT
#     addr: 0xc3fa0308
#     size_bits: 32
#     description: eMIOS_0 UC23 CNT
#   - !Register
#     name: EMIOS0_UC23_SC
#     addr: 0xc3fa030c
#     size_bits: 32
#     description: eMIOS_0 UC23 Control Register
#   - !Register
#     name: EMIOS0_UC23_SS
#     addr: 0xc3fa0310
#     size_bits: 32
#     description: eMIOS_0 UC23 Status Register
# - !Module
#   name: eMIOS_1
#   base_addr: 0xc3fa4000
#   registers:
#   - !Register
#     name: eMIOS1_MCR
#     addr: 0xc3fa4000
#     size_bits: 32
#     description: EMIOS Module Configuration Register
#   - !Register
#     name: eMIOS1_GFLAG
#     addr: 0xc3fa4004
#     size_bits: 32
#     description: EMIOS Global FLAG Register
#   - !Register
#     name: eMIOS1_OUDIS
#     addr: 0xc3fa4008
#     size_bits: 32
#     description: EMIOS Output Update Disable Register
#   - !Register
#     name: eMIOS1_UCDIS
#     addr: 0xc3fa400c
#     size_bits: 32
#     description: EMIOS   Disable Channel Register
#   - !Register
#     name: eMIOS1_UC0_A
#     addr: 0xc3fa4020
#     size_bits: 32
#     description: eMIOS_1 UC0 A Register
#   - !Register
#     name: eMIOS1_UC0_B
#     addr: 0xc3fa4024
#     size_bits: 32
#     description: eMIOS_1 UC0 B Register
#   - !Register
#     name: eMIOS1_UC0_CNT
#     addr: 0xc3fa4028
#     size_bits: 32
#     description: eMIOS_1 UC0 CNT
# ...
#   - !Register
#     name: RXIMR60
#     addr: 0xfffd0970
#     size_bits: 32
#     description: RX Individual Mask Register 60
#   - !Register
#     name: RXIMR61
#     addr: 0xfffd0974
#     size_bits: 32
#     description: RX Individual Mask Register 61
#   - !Register
#     name: RXIMR62
#     addr: 0xfffd0978
#     size_bits: 32
#     description: RX Individual Mask Register 62
#   - !Register
#     name: RXIMR63
#     addr: 0xfffd097c
#     size_bits: 32
#     description: RX Individual Mask Register 63
# - !Module
#   name: CAN5
#   base_addr: 0xfffd4000
#   registers:
#   - !Register
#     name: MCR
#     addr: 0xfffd4000
#     size_bits: 32
#     description: Module Configuration
#   - !Register
#     name: CTRL
#     addr: 0xfffd4004
#     size_bits: 32
#     description: Control Register
#   - !Register
#     name: TIMER
#     addr: 0xfffd4008
#     size_bits: 32
#     description: Free Running Timer
#   - !Register
#     name: RXGMASK
#     addr: 0xfffd4010
#     size_bits: 32
#     description: Rx Global Mask Register
#   - !Register
#     name: RX14MASK
#     addr: 0xfffd4014
#     size_bits: 32
#     description: Rx 14 Mask Register
#   - !Register
#     name: RX15MASK
#     addr: 0xfffd4018
#     size_bits: 32
#     description: Rx 15 Mask Register
#   - !Register
#     name: ECR
#     addr: 0xfffd401c
#     size_bits: 32
#     description: Error Counter Register
#   - !Register
#     name: ESR
#     addr: 0xfffd4020
#     size_bits: 32
#     description: Error and Status Register
#   - !Register
#     name: IMASK2
#     addr: 0xfffd4024
#     size_bits: 32
#     description: Interrupt Masks 2 Register
#   - !Register
#     name: IMASK1
#     addr: 0xfffd4028
#     size_bits: 32
#     description: Interrupt Masks 1 Register
#   - !Register
#     name: IFLAG2
#     addr: 0xfffd402c
#     size_bits: 32
#     description: Interrupt Flags 2 Register
#   - !Register
#     name: IFLAG1
#     addr: 0xfffd4030
#     size_bits: 32
#     description: Interrupt Flags 1 Register
#   - !Register
#     name: MB0
#     addr: 0xfffd4080
#     size_bits: 8
#     description: Message Buffer 0
#   - !Register
#     name: MB1
#     addr: 0xfffd4090
#     size_bits: 8
#     description: Message Buffer 1
#   - !Register
#     name: MB2
#     addr: 0xfffd40a0
#     size_bits: 8
#     description: Message Buffer 2
#   - !Register
#     name: MB3
#     addr: 0xfffd40b0
#     size_bits: 8
#     description: Message Buffer 3
#   - !Register
#     name: MB4
#     addr: 0xfffd40c0
#     size_bits: 8
#     description: Message Buffer 4
#   - !Register
#     name: MB5
#     addr: 0xfffd40d0
#     size_bits: 8
#     description: Message Buffer 5
#   - !Register
#     name: MB6
#     addr: 0xfffd40e0
#     size_bits: 8
#     description: Message Buffer 6
#   - !Register
#     name: MB7
#     addr: 0xfffd40f0
#     size_bits: 8
#     description: Message Buffer 7
#   - !Register
#     name: MB8
#     addr: 0xfffd4100
#     size_bits: 8
#     description: Message Buffer 8
#   - !Register
#     name: MB9
#     addr: 0xfffd4110
#     size_bits: 8
#     description: Message Buffer 9
#   - !Register
#     name: MB10
#     addr: 0xfffd4120
#     size_bits: 8
#     description: Message Buffer 10
#   - !Register
#     name: MB11
#     addr: 0xfffd4130
#     size_bits: 8
#     description: Message Buffer 11
#   - !Register
#     name: MB12
#     addr: 0xfffd4140
#     size_bits: 8
#     description: Message Buffer 12
#   - !Register
#     name: MB13
#     addr: 0xfffd4150
#     size_bits: 8
#     description: Message Buffer 13
#   - !Register
#     name: MB14
#     addr: 0xfffd4160
#     size_bits: 8
#     description: Message Buffer 14
#   - !Register
#     name: MB15
#     addr: 0xfffd4170
#     size_bits: 8
#     description: Message Buffer 15
#   - !Register
#     name: MB16
#     addr: 0xfffd4180
#     size_bits: 8
#     description: Message Buffer 16
#   - !Register
#     name: MB17
#     addr: 0xfffd4190
#     size_bits: 8
#     description: Message Buffer 17
#   - !Register
#     name: MB18
#     addr: 0xfffd41a0
#     size_bits: 8
#     description: Message Buffer 18
#   - !Register
#     name: MB19
#     addr: 0xfffd41b0
#     size_bits: 8
#     description: Message Buffer 19
#   - !Register
#     name: MB20
#     addr: 0xfffd41c0
#     size_bits: 8
#     description: Message Buffer 20
#   - !Register
#     name: MB21
#     addr: 0xfffd41d0
#     size_bits: 8
#     description: Message Buffer 21
#   - !Register
#     name: MB22
#     addr: 0xfffd41e0
#     size_bits: 8
#     description: Message Buffer 22
#   - !Register
#     name: MB23
#     addr: 0xfffd41f0
#     size_bits: 8
#     description: Message Buffer 23
#   - !Register
#     name: MB24
#     addr: 0xfffd4200
#     size_bits: 8
#     description: Message Buffer 24
#   - !Register
#     name: MB25
#     addr: 0xfffd4210
#     size_bits: 8
#     description: Message Buffer 25
#   - !Register
#     name: MB26
#     addr: 0xfffd4220
#     size_bits: 8
#     description: Message Buffer 26
#   - !Register
#     name: MB27
#     addr: 0xfffd4230
#     size_bits: 8
#     description: Message Buffer 27
#   - !Register
#     name: MB28
#     addr: 0xfffd4240
#     size_bits: 8
#     description: Message Buffer 28
#   - !Register
#     name: MB29
#     addr: 0xfffd4250
#     size_bits: 8
#     description: Message Buffer 29
#   - !Register
#     name: MB30
#     addr: 0xfffd4260
#     size_bits: 8
#     description: Message Buffer 30
#   - !Register
#     name: MB31
#     addr: 0xfffd4270
#     size_bits: 8
#     description: Message Buffer 31
#   - !Register
#     name: MB32
#     addr: 0xfffd4280
#     size_bits: 8
#     description: Message Buffer 32
#   - !Register
#     name: MB33
#     addr: 0xfffd4290
#     size_bits: 8
#     description: Message Buffer 33
#   - !Register
#     name: MB34
#     addr: 0xfffd42a0
#     size_bits: 8
#     description: Message Buffer 34
#   - !Register
#     name: MB35
#     addr: 0xfffd42b0
#     size_bits: 8
#     description: Message Buffer 35
#   - !Register
#     name: MB36
#     addr: 0xfffd42c0
#     size_bits: 8
#     description: Message Buffer 36
#   - !Register
#     name: MB37
#     addr: 0xfffd42d0
#     size_bits: 8
#     description: Message Buffer 37
#   - !Register
#     name: MB38
#     addr: 0xfffd42e0
#     size_bits: 8
#     description: Message Buffer 38
#   - !Register
#     name: MB39
#     addr: 0xfffd42f0
#     size_bits: 8
#     description: Message Buffer 39
#   - !Register
#     name: MB40
#     addr: 0xfffd4300
#     size_bits: 8
#     description: Message Buffer 40
#   - !Register
#     name: MB41
#     addr: 0xfffd4310
#     size_bits: 8
#     description: Message Buffer 41
#   - !Register
#     name: MB42
#     addr: 0xfffd4320
#     size_bits: 8
#     description: Message Buffer 42
#   - !Register
#     name: MB43
#     addr: 0xfffd4330
#     size_bits: 8
#     description: Message Buffer 43
#   - !Register
#     name: MB44
#     addr: 0xfffd4340
#     size_bits: 8
#     description: Message Buffer 44
#   - !Register
#     name: MB45
#     addr: 0xfffd4350
#     size_bits: 8
#     description: Message Buffer 45
#   - !Register
#     name: MB46
#     addr: 0xfffd4360
#     size_bits: 8
#     description: Message Buffer 46
#   - !Register
#     name: MB47
#     addr: 0xfffd4370
#     size_bits: 8
#     description: Message Buffer 47
#   - !Register
#     name: MB48
#     addr: 0xfffd4380
#     size_bits: 8
#     description: Message Buffer 48
#   - !Register
#     name: MB49
#     addr: 0xfffd4390
#     size_bits: 8
#     description: Message Buffer 49
#   - !Register
#     name: MB50
#     addr: 0xfffd43a0
#     size_bits: 8
#     description: Message Buffer 50
#   - !Register
#     name: MB51
#     addr: 0xfffd43b0
#     size_bits: 8
#     description: Message Buffer 51
#   - !Register
#     name: MB52
#     addr: 0xfffd43c0
#     size_bits: 8
#     description: Message Buffer 52
#   - !Register
#     name: MB53
#     addr: 0xfffd43d0
#     size_bits: 8
#     description: Message Buffer 53
#   - !Register
#     name: MB54
#     addr: 0xfffd43e0
#     size_bits: 8
#     description: Message Buffer 54
#   - !Register
#     name: MB55
#     addr: 0xfffd43f0
#     size_bits: 8
#     description: Message Buffer 55
#   - !Register
#     name: MB56
#     addr: 0xfffd4400
#     size_bits: 8
#     description: Message Buffer 56
#   - !Register
#     name: MB57
#     addr: 0xfffd4410
#     size_bits: 8
#     description: Message Buffer 57
#   - !Register
#     name: MB58
#     addr: 0xfffd4420
#     size_bits: 8
#     description: Message Buffer 58
#   - !Register
#     name: MB59
#     addr: 0xfffd4430
#     size_bits: 8
#     description: Message Buffer 59
#   - !Register
#     name: MB60
#     addr: 0xfffd4440
#     size_bits: 8
#     description: Message Buffer 60
#   - !Register
#     name: MB61
#     addr: 0xfffd4450
#     size_bits: 8
#     description: Message Buffer 61
#   - !Register
#     name: MB62
#     addr: 0xfffd4460
#     size_bits: 8
#     description: Message Buffer 62
#   - !Register
#     name: MB63
#     addr: 0xfffd4470
#     size_bits: 8
#     description: Message Buffer 63
#   - !Register
#     name: RXIMR0
#     addr: 0xfffd4880
#     size_bits: 32
#     description: RX Individual Mask Register 0
#   - !Register
#     name: RXIMR1
#     addr: 0xfffd4884
#     size_bits: 32
#     description: RX Individual Mask Register 1
#   - !Register
#     name: RXIMR2
#     addr: 0xfffd4888
#     size_bits: 32
#     description: RX Individual Mask Register 2
#   - !Register
#     name: RXIMR3
#     addr: 0xfffd488c
#     size_bits: 32
#     description: RX Individual Mask Register 3
#   - !Register
#     name: RXIMR4
#     addr: 0xfffd4890
#     size_bits: 32
#     description: RX Individual Mask Register 4
#   - !Register
#     name: RXIMR5
#     addr: 0xfffd4894
#     size_bits: 32
#     description: RX Individual Mask Register 5
#   - !Register
#     name: RXIMR6
#     addr: 0xfffd4898
#     size_bits: 32
#     description: RX Individual Mask Register 6
#   - !Register
#     name: RXIMR7
#     addr: 0xfffd489c
#     size_bits: 32
#     description: RX Individual Mask Register 7
#   - !Register
#     name: RXIMR8
#     addr: 0xfffd48a0
#     size_bits: 32
#     description: RX Individual Mask Register 8
#   - !Register
#     name: RXIMR9
#     addr: 0xfffd48a4
#     size_bits: 32
#     description: RX Individual Mask Register 9
#   - !Register
#     name: RXIMR10
#     addr: 0xfffd48a8
#     size_bits: 32
#     description: RX Individual Mask Register 10
#   - !Register
#     name: RXIMR11
#     addr: 0xfffd48ac
#     size_bits: 32
#     description: RX Individual Mask Register 11
#   - !Register
#     name: RXIMR12
#     addr: 0xfffd48b0
#     size_bits: 32
#     description: RX Individual Mask Register 12
#   - !Register
#     name: RXIMR13
#     addr: 0xfffd48b4
#     size_bits: 32
#     description: RX Individual Mask Register 13
#   - !Register
#     name: RXIMR14
#     addr: 0xfffd48b8
#     size_bits: 32
#     description: RX Individual Mask Register 14
#   - !Register
#     name: RXIMR15
#     addr: 0xfffd48bc
#     size_bits: 32
#     description: RX Individual Mask Register 15
#   - !Register
#     name: RXIMR16
#     addr: 0xfffd48c0
#     size_bits: 32
#     description: RX Individual Mask Register 16
#   - !Register
#     name: RXIMR17
#     addr: 0xfffd48c4
#     size_bits: 32
#     description: RX Individual Mask Register 17
#   - !Register
#     name: RXIMR18
#     addr: 0xfffd48c8
#     size_bits: 32
#     description: RX Individual Mask Register 18
#   - !Register
#     name: RXIMR19
#     addr: 0xfffd48cc
#     size_bits: 32
#     description: RX Individual Mask Register 19
#   - !Register
#     name: RXIMR20
#     addr: 0xfffd48d0
#     size_bits: 32
#     description: RX Individual Mask Register 20
#   - !Register
#     name: RXIMR21
#     addr: 0xfffd48d4
#     size_bits: 32
#     description: RX Individual Mask Register 21
#   - !Register
#     name: RXIMR22
#     addr: 0xfffd48d8
#     size_bits: 32
#     description: RX Individual Mask Register 22
#   - !Register
#     name: RXIMR23
#     addr: 0xfffd48dc
#     size_bits: 32
#     description: RX Individual Mask Register 23
#   - !Register
#     name: RXIMR24
#     addr: 0xfffd48e0
#     size_bits: 32
#     description: RX Individual Mask Register 24
#   - !Register
#     name: RXIMR25
#     addr: 0xfffd48e4
#     size_bits: 32
#     description: RX Individual Mask Register 25
#   - !Register
#     name: RXIMR26
#     addr: 0xfffd48e8
#     size_bits: 32
#     description: RX Individual Mask Register 26
#   - !Register
#     name: RXIMR27
#     addr: 0xfffd48ec
#     size_bits: 32
#     description: RX Individual Mask Register 27
#   - !Register
#     name: RXIMR28
#     addr: 0xfffd48f0
#     size_bits: 32
#     description: RX Individual Mask Register 28
#   - !Register
#     name: RXIMR29
#     addr: 0xfffd48f4
#     size_bits: 32
#     description: RX Individual Mask Register 29
#   - !Register
#     name: RXIMR30
#     addr: 0xfffd48f8
#     size_bits: 32
#     description: RX Individual Mask Register 30
#   - !Register
#     name: RXIMR31
#     addr: 0xfffd48fc
#     size_bits: 32
#     description: RX Individual Mask Register 31
#   - !Register
#     name: RXIMR32
#     addr: 0xfffd4900
#     size_bits: 32
#     description: RX Individual Mask Register 32
#   - !Register
#     name: RXIMR33
#     addr: 0xfffd4904
#     size_bits: 32
#     description: RX Individual Mask Register 33
#   - !Register
#     name: RXIMR34
#     addr: 0xfffd4908
#     size_bits: 32
#     description: RX Individual Mask Register 34
#   - !Register
#     name: RXIMR35
#     addr: 0xfffd490c
#     size_bits: 32
#     description: RX Individual Mask Register 35
#   - !Register
#     name: RXIMR36
#     addr: 0xfffd4910
#     size_bits: 32
#     description: RX Individual Mask Register 36
#   - !Register
#     name: RXIMR37
#     addr: 0xfffd4914
#     size_bits: 32
#     description: RX Individual Mask Register 37
#   - !Register
#     name: RXIMR38
#     addr: 0xfffd4918
#     size_bits: 32
#     description: RX Individual Mask Register 38
#   - !Register
#     name: RXIMR39
#     addr: 0xfffd491c
#     size_bits: 32
#     description: RX Individual Mask Register 39
#   - !Register
#     name: RXIMR40
#     addr: 0xfffd4920
#     size_bits: 32
#     description: RX Individual Mask Register 40
#   - !Register
#     name: RXIMR41
#     addr: 0xfffd4924
#     size_bits: 32
#     description: RX Individual Mask Register 41
#   - !Register
#     name: RXIMR42
#     addr: 0xfffd4928
#     size_bits: 32
#     description: RX Individual Mask Register 42
#   - !Register
#     name: RXIMR43
#     addr: 0xfffd492c
#     size_bits: 32
#     description: RX Individual Mask Register 43
#   - !Register
#     name: RXIMR44
#     addr: 0xfffd4930
#     size_bits: 32
#     description: RX Individual Mask Register 44
#   - !Register
#     name: RXIMR45
#     addr: 0xfffd4934
#     size_bits: 32
#     description: RX Individual Mask Register 45
#   - !Register
#     name: RXIMR46
#     addr: 0xfffd4938
#     size_bits: 32
#     description: RX Individual Mask Register 46
#   - !Register
#     name: RXIMR47
#     addr: 0xfffd493c
#     size_bits: 32
#     description: RX Individual Mask Register 47
#   - !Register
#     name: RXIMR48
#     addr: 0xfffd4940
#     size_bits: 32
#     description: RX Individual Mask Register 48
#   - !Register
#     name: RXIMR49
#     addr: 0xfffd4944
#     size_bits: 32
#     description: RX Individual Mask Register 49
#   - !Register
#     name: RXIMR50
#     addr: 0xfffd4948
#     size_bits: 32
#     description: RX Individual Mask Register 50
#   - !Register
#     name: RXIMR51
#     addr: 0xfffd494c
#     size_bits: 32
#     description: RX Individual Mask Register 51
#   - !Register
#     name: RXIMR52
#     addr: 0xfffd4950
#     size_bits: 32
#     description: RX Individual Mask Register 52
#   - !Register
#     name: RXIMR53
#     addr: 0xfffd4954
#     size_bits: 32
#     description: RX Individual Mask Register 53
#   - !Register
#     name: RXIMR54
#     addr: 0xfffd4958
#     size_bits: 32
#     description: RX Individual Mask Register 54
#   - !Register
#     name: RXIMR55
#     addr: 0xfffd495c
#     size_bits: 32
#     description: RX Individual Mask Register 55
#   - !Register
#     name: RXIMR56
#     addr: 0xfffd4960
#     size_bits: 32
#     description: RX Individual Mask Register 56
#   - !Register
#     name: RXIMR57
#     addr: 0xfffd4964
#     size_bits: 32
#     description: RX Individual Mask Register 57
#   - !Register
#     name: RXIMR58
#     addr: 0xfffd4968
#     size_bits: 32
#     description: RX Individual Mask Register 58
#   - !Register
#     name: RXIMR59
#     addr: 0xfffd496c
#     size_bits: 32
#     description: RX Individual Mask Register 59
#   - !Register
#     name: RXIMR60
#     addr: 0xfffd4970
#     size_bits: 32
#     description: RX Individual Mask Register 60
#   - !Register
#     name: RXIMR61
#     addr: 0xfffd4974
#     size_bits: 32
#     description: RX Individual Mask Register 61
#   - !Register
#     name: RXIMR62
#     addr: 0xfffd4978
#     size_bits: 32
#     description: RX Individual Mask Register 62
#   - !Register
#     name: RXIMR63
#     addr: 0xfffd497c
#     size_bits: 32
#     description: RX Individual Mask Register 63

# %%
# Commit to file
with open(DEFINITIONS_DIR + f"/{dev.manufacturer}/{dev.part_number}.yaml", 'w') as f:
    f.write(dev.dump())
